# %% [markdown]
# # ch7.9 BIC
# 以西瓜数据集2.0为训练集，试基于BIC准则（贝叶斯信息准则）构建一个贝叶斯网。

# %%
import numpy as np
import pandas as pd
import collections as col
import math
from graphviz import Digraph
import matplotlib.pyplot as plt
import BayesNetwork as bn

# %%
C = bayesNet.createNode("C", 0.001)
T = bayesNet.createNode("T", 0.002)
A = bayesNet.createNode("A", [0.95, 0.94, 0.29, 0.001], parents=[T, C])
M = bayesNet.createNode("M", [0.90, 0.05], parents=A)
J = bayesNet.createNode("J", [0.70, 0.01], parents=A)
bayesNet.drawGraph(show=True)
bayesNet.defaultComputeMethod = 'exp2'

# %%
dataset = pd.read_csv('data/table_4_3_watermelon_3_0_num.csv')
dataset = dataset.drop('Idx',axis=1)
dataset = dataset.drop('density', axis=1)
dataset = dataset.drop('sugar_ratio', axis=1)
test_data = dataset.ix[0,:]
# Out:
#     color  root  knocks  texture  navel  touch  density  sugar_ratio  label
# 0       0     0       0        0      0      0    0.697        0.460      1
# 1       1     0       1        0      0      0    0.774        0.376      1
# 2       1     0       0        0      0      0    0.634        0.264      1
# 3       0     0       1        0      0      0    0.608        0.318      1
# 4       2     0       0        0      0      0    0.556        0.215      1
# 5       0     1       0        0      1      1    0.403        0.237      1
# 6       1     1       0        1      1      1    0.481        0.149      1
# 7       1     1       0        0      1      0    0.437        0.211      1
# 8       1     1       1        1      1      0    0.666        0.091      0
# 9       0     2       2        0      2      1    0.243        0.267      0
# 10      2     2       2        2      2      0    0.245        0.057      0
# 11      2     0       0        2      2      1    0.343        0.099      0
# 12      0     1       0        1      0      0    0.639        0.161      0
# 13      2     1       1        1      0      0    0.657        0.198      0
# 14      1     1       0        0      1      1    0.360        0.370      0
# 15      2     0       0        2      2      0    0.593        0.042      0
# 16      0     0       1        1      1      0    0.719        0.103      0

# %%
cn = dataset.columns[:-1]

# %%
bayesNet = bn.Network()
bayesNet.
